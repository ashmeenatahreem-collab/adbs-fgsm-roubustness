# %% [markdown]
# <a href="https://colab.research.google.com/github/ashmeenatahreem-collab/adbs-fgsm-roubustness/blob/main/notebooks/00_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python is working.")
# Out:
# Hello! Python is working.

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA (GPU) available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("ERROR: GPU is not available. Go to Runtime -> Change runtime type -> select T4 GPU.")
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA (GPU) available: True
# GPU Name: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# Check if our project folder exists in Drive
path = '/content/drive/MyDrive/ADS-B-FGSM-Project'
if os.path.exists(path):
    print("SUCCESS: Connected to ADS-B-FGSM-Project folder!")
    print("Subfolders found:", os.listdir(path))
else:
    print("ERROR: Folder not found. Check spelling and sharing permissions.")
# Out:
# ERROR: Folder not found. Check spelling and sharing permissions.

# %%
import os

# Check if our project folder exists in Drive
path = '/content/drive/MyDrive/IEEE/MAJOR PROJECT'

if os.path.exists(path):
    print("SUCCESS: Connected to IEEE/MAJOR PROJECT folder!")
    print("Subfolders found:", os.listdir(path))
else:
    print("ERROR: Folder not found. Check spelling and sharing permissions.")
# Out:
# ERROR: Folder not found. Check spelling and sharing permissions.

# %%
import os
# Check if our project folder exists in Drive
# REPLACE 'IEEE MAJOR PROJECT' with the EXACT name you used
path = '/content/drive/MyDrive/IEEE MAJOR PROJECT'
if os.path.exists(path):
    print("SUCCESS: Connected to IEEE MAJOR PROJECT folder!")
    print("Subfolders found:", os.listdir(path))
else:
    print("ERROR: Folder not found. Check spelling and sharing permissions.")
# Out:
# SUCCESS: Connected to IEEE MAJOR PROJECT folder!
# Subfolders found: ['data', 'models', 'results', 'screenshots', 'paper_drafts', 'videos']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = '/content/drive/MyDrive/IEEE MAJOR PROJECT'

if os.path.exists(path):
    print("SUCCESS: Connected to IEEE MAJOR PROJECT!")
    print("Subfolders found:", os.listdir(path))
else:
    print("ERROR: Folder not found.")
    print("Folders actually in My Drive:")
    for f in os.listdir('/content/drive/MyDrive'):
        print(" -", f)
# Out:
# SUCCESS: Connected to IEEE MAJOR PROJECT!
# Subfolders found: ['data', 'models', 'results', 'screenshots', 'paper_drafts', 'videos']

# %%
import os

# Check if the folder is now visible in My Drive
# (Replace 'ADS-B-FGSM-Project' with the exact name your teammate used if it's different)
path = '/content/drive/MyDrive/ADS-B-FGSM-Project'

if os.path.exists(path):
    print("✅ SUCCESS: Folder is now connected!")
    print("Subfolders found:", os.listdir(path))
else:
    print("❌ Still not found. Trying alternate name...")
    path2 = '/content/drive/MyDrive/IEEE MAJOR PROJECT'
    if os.path.exists(path2):
        print("✅ SUCCESS: Found 'IEEE MAJOR PROJECT'!")
        print("Subfolders found:", os.listdir(path2))
    else:
        print("❌ ERROR: Still not found. Please double-check the exact folder name in 'Shared with me'.")
# Out:
# ❌ Still not found. Trying alternate name...
# ✅ SUCCESS: Found 'IEEE MAJOR PROJECT'!
# Subfolders found: ['data', 'models', 'results', 'screenshots', 'paper_drafts', 'videos']

# %%
import os

path = '/content/drive/MyDrive/IEEE MAJOR PROJECT'

if os.path.exists(path):
    print("SUCCESS: Connected to IEEE MAJOR PROJECT folder!")
    print("Subfolders found:", os.listdir(path))
else:
    print("ERROR: Folder not found. Check spelling and sharing permissions.")
# Out:
# SUCCESS: Connected to IEEE MAJOR PROJECT folder!
# Subfolders found: ['data', 'models', 'results', 'screenshots', 'paper_drafts', 'videos']
